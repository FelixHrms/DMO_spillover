# %%
import pyodbc
import pandas as pd
import numpy as np

cnxn = pyodbc.connect('DSN=Hermes_DSN',autocommit=True)
cursor = cnxn.cursor()

# %% [markdown]
# # MMSR banks

# %%
# Data prep
query = f"""

SELECT *
FROM xlab_ecb_prj_sftds_cb_common.hermesf_state 

"""

df = pd.read_sql_query(query, cnxn)
# Out:
# C:\Users\hermesf\AppData\Local\Temp\ipykernel_12180\3399904493.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_agg = pd.read_sql_query(query, cnxn)
